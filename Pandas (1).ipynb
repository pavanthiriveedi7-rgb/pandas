# %% [markdown]
# pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Series**

# %%
s1 = pd.Series([24,1,5,66,88,99])
s1
# Out:
# 0    24
# 1     1
# 2     5
# 3    66
# 4    88
# 5    99
# dtype: int64

# %%
s2 = pd.Series([24,1,5,66,88,99],index = {'pavan','gopi','hulk','gouse','sam','ram'})
s2
# Out:
# pavan    24
# ram       1
# hulk      5
# sam      66
# gopi     88
# gouse    99
# dtype: int64

# %%
s1
# Out:
# 0    24
# 1     1
# 2     5
# 3    66
# 4    88
# 5    99
# dtype: int64

# %%
s3 = pd.Series([24,1,5,66,88,99],index={'pavan','gopi','hulk','gouse','sam','ram'},dtype = float)
s2
# Out:
# pavan    24.0
# ram       1.0
# hulk      5.0
# sam      66.0
# gopi     88.0
# gouse    99.0
# dtype: float64

# %%
s3['pavan']
# Out:
# np.float64(24.0)

# %%
s3[0]
# Out:
# /tmp/ipython-input-397937684.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s3[0]
# np.float64(24.0)

# %%
s3["hulk"]
# Out:
# np.float64(5.0)

# %%
students = pd.Series(['pavan','gopi','hulk','gouse','sam','ram'],index = ["I","II","III","IV","V","VI"])
students
# Out:
# I      pavan
# II      gopi
# III     hulk
# IV     gouse
# V        sam
# VI       ram
# dtype: object

# %%
students["I"]
# Out:
# 'pavan'

# %%
students["VI"]
# Out:
# 'ram'

# %%
students[3]
# Out:
# /tmp/ipython-input-1158474101.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   students[3]
# 'gouse'

# %% [markdown]
# Creation of series using Dictionary

# %%
s4 = pd.Series({'a': 1, 'v' : 2, 'c': 3,'d' : 4})
s4
# Out:
# a    1
# v    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# **Dataframe**

# %%
s1 = pd.DataFrame([24,1,5,66,88,99])
s1
# Out:
#     0
# 0  24
# 1   1
# 2   5
# 3  66
# 4  88
# 5  99

# %%
d2 = pd.DataFrame([10,20,30],[40,50,60])
d2
# Out:
#      0
# 40  10
# 50  20
# 60  30

# %%
d2 = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])
d2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
students
# Out:
# I      pavan
# II      gopi
# III     hulk
# IV     gouse
# V        sam
# VI       ram
# dtype: object

# %%
# convert to series to DataFrame
d2 = pd.DataFrame(students)
d2
# Out:
#          0
# I    pavan
# II    gopi
# III   hulk
# IV   gouse
# V      sam
# VI     ram

# %%
d3 = pd.DataFrame([[70,80,90],[40,50,60],[10,20,30]],columns = ["maths","phy","chemstry"],index = ["pavan","gopi","Hulk"])
d3
# Out:
#        maths  phy  chemstry
# pavan     70   80        90
# gopi      40   50        60
# Hulk      10   20        30

# %%
d2
#students
# Out:
#          0
# I    pavan
# II    gopi
# III   hulk
# IV   gouse
# V      sam
# VI     ram

# %%
dictionary = [{'pa1':1,'gop':2,'bro':4},{'pa1':55,'bro':45,'didi':00}]
dictionary
# Out:
# [{'pa1': 1, 'gop': 2, 'bro': 4}, {'pa1': 55, 'bro': 45, 'didi': 0}]

# %%
dictionary = [{'pa1':1,'gop':2,'bro':4},{'pa1':55,'bro':45,'didi':00}]
pd.DataFrame(dictionary,index = ['x','y'],dtype = float)
# Out:
#     pa1  gop   bro  didi
# x   1.0  2.0   4.0   NaN
# y  55.0  NaN  45.0   0.0

# %%
dictionary = [{'pa1':1,'gop':2,'bro':4},{'pa1':55,'bro':45,'didi':00}]
pd.DataFrame(dictionary,index = ['x','y'],dtype = int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipython-input-3375108835.py in <cell line: 0>()
#       1 dictionary = [{'pa1':1,'gop':2,'bro':4},{'pa1':55,'bro':45,'didi':00}]
# ----> 2 pd.DataFrame(dictionary,index = ['x','y'],dtype = int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     857                         dtype,
#     858                     )
# --> 859                     mgr = arrays_to_mgr(
#     860                         arrays,
#     861                         columns,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117
#     118         # don't force copy because getting jammed in an ndarray anyway
# ...

# %% [markdown]
# **DataFrame operations**

# %%
marks = pd.DataFrame([[70,80,90],[40,50,60],[10,20,30]],columns = ["maths","phy","chemstry"],index = ["pavan","gopi","Hulk"])
marks
# Out:
#        maths  phy  chemstry
# pavan     70   80        90
# gopi      40   50        60
# Hulk      10   20        30

# %%
marks['chemstry']
# Out:
# pavan    90
# gopi     60
# Hulk     30
# Name: chemstry, dtype: int64

# %%
marks['phy']
# Out:
# pavan    80
# gopi     50
# Hulk     20
# Name: phy, dtype: int64

# %%
marks['maths']['pavan']
# Out:
# np.int64(70)

# %%
marks['maths']['gopi']
# Out:
# np.int64(40)

# %%
marks['Total'] = marks['maths']+marks['phy']+marks['chemstry']
marks
# Out:
#        maths  phy  chemstry  Total
# pavan     70   80        90    240
# gopi      40   50        60    150
# Hulk      10   20        30     60

# %%
marks["percantage"] = (marks['Total']/300)*100
marks
# Out:
#        maths  phy  chemstry  Total  percantage
# pavan     70   80        90    240        80.0
# gopi      40   50        60    150        50.0
# Hulk      10   20        30     60        20.0

# %%
marks.percantage
# Out:
# pavan    80.0
# gopi     50.0
# Hulk     20.0
# Name: percantage, dtype: float64

# %%
marks.Total
# Out:
# pavan    240
# gopi     150
# Hulk      60
# Name: Total, dtype: int64

# %%
pop = marks.pop('phy')
pop
# Out:
# pavan    80
# gopi     50
# Hulk     20
# Name: phy, dtype: int64

# %%
marks
# Out:
#        maths  phy  chemstry  Total  percantage
# pavan     70   80        90    240        80.0
# gopi      40   50        60    150        50.0
# Hulk      10   20        30     60        20.0

# %%
marks.insert(3,"Qc",[99,97,95])
marks
# Out:
#        maths  phy  chemstry  Qc  Total  percantage
# pavan     70   80        90  99    240        80.0
# gopi      40   50        60  97    150        50.0
# Hulk      10   20        30  95     60        20.0

# %%
d4 = pd.DataFrame({'ram':np.random.randint(1,10,size = (30)),'pa1':np.random.randint(2,10,size = (30)),'Hulk':np.random.randint(3,10,size = (30))})
d4
# Out:
#     ram  pa1  Hulk
# 0     2    4     7
# 1     4    8     3
# 2     8    9     9
# 3     7    8     4
# 4     1    5     5
# 5     9    9     3
# 6     4    9     7
# 7     3    2     5
# 8     1    6     6
# 9     6    2     3
# 10    5    5     7
# 11    8    6     5
# 12    5    9     4
# 13    8    4     3
# 14    4    2     6
# 15    4    8     7
# 16    4    9     4
# 17    5    8     3
# 18    6    8     6
# 19    2    3     7
# 20    5    6     6
# 21    7    6     5
# 22    9    4     6
# 23    6    7     5
# 24    4    2     9
# 25    8    8     5
# 26    4    3     5
# 27    8    7     3
# 28    3    4     5
# 29    9    5     5

# %%
d4.head()
# Out:
#    ram  pa1  Hulk
# 0    2    4     7
# 1    4    8     3
# 2    8    9     9
# 3    7    8     4
# 4    1    5     5

# %%
d4.head(10)
# Out:
#    ram  pa1  Hulk
# 0    2    4     7
# 1    4    8     3
# 2    8    9     9
# 3    7    8     4
# 4    1    5     5
# 5    9    9     3
# 6    4    9     7
# 7    3    2     5
# 8    1    6     6
# 9    6    2     3

# %%
d4.tail()
# Out:
#     ram  pa1  Hulk
# 25    8    8     5
# 26    4    3     5
# 27    8    7     3
# 28    3    4     5
# 29    9    5     5

# %%
d4.tail(5)
# Out:
#     ram  pa1  Hulk
# 25    8    8     5
# 26    4    3     5
# 27    8    7     3
# 28    3    4     5
# 29    9    5     5

# %%
d4.loc[10,"pa1"]
# Out:
# np.int64(5)

# %%
d4.loc[11,"ram"]
# Out:
# np.int64(8)

# %%
d4.loc[10:19,'pa1']
# Out:
# 10    5
# 11    6
# 12    9
# 13    4
# 14    2
# 15    8
# 16    9
# 17    8
# 18    8
# 19    3
# Name: pa1, dtype: int64

# %%
d4.loc[16:9,"pa1"]
# Out:
# Series([], Name: pa1, dtype: int64)

# %%
d4.loc[10:16,["pa1","ram"]]
# Out:
#     pa1  ram
# 10    5    5
# 11    6    8
# 12    9    5
# 13    4    8
# 14    2    4
# 15    8    4
# 16    9    4

# %%
d4.loc[10:16,["Hulk","ram"]]
# Out:
#     Hulk  ram
# 10     7    5
# 11     5    8
# 12     4    5
# 13     3    8
# 14     6    4
# 15     7    4
# 16     4    4

# %%
d4.tail(10)
# Out:
#     ram  pa1  Hulk
# 20    5    6     6
# 21    7    6     5
# 22    9    4     6
# 23    6    7     5
# 24    4    2     9
# 25    8    8     5
# 26    4    3     5
# 27    8    7     3
# 28    3    4     5
# 29    9    5     5

# %%
d4.iloc[4,1]  # index = 4 and coluhms = 1 as 2nd columns
# Out:
# np.int64(5)

# %%
d4.iloc[4:9,[0,2]]
# Out:
#    ram  Hulk
# 4    1     5
# 5    9     3
# 6    4     7
# 7    3     5
# 8    1     6

# %%
d4.iloc[[1,5,6,9,8,7,4,5,6,4,2,3,3,3]]
# Out:
#    ram  pa1  Hulk
# 1    4    8     3
# 5    9    9     3
# 6    4    9     7
# 9    6    2     3
# 8    1    6     6
# 7    3    2     5
# 4    1    5     5
# 5    9    9     3
# 6    4    9     7
# 4    1    5     5
# 2    8    9     9
# 3    7    8     4
# 3    7    8     4
# 3    7    8     4

# %%
d4.pa1
# Out:
# 0     4
# 1     8
# 2     9
# 3     8
# 4     5
# 5     9
# 6     9
# 7     2
# 8     6
# 9     2
# 10    5
# 11    6
# 12    9
# 13    4
# 14    2
# 15    8
# 16    9
# 17    8
# 18    8
# 19    3
# 20    6
# 21    6
# 22    4
# 23    7
# 24    2
# 25    8
# 26    3
# 27    7
# 28    4
# 29    5
# Name: pa1, dtype: int64

# %%
d4["pa1"]
# Out:
# 0     4
# 1     8
# 2     9
# 3     8
# 4     5
# 5     9
# 6     9
# 7     2
# 8     6
# 9     2
# 10    5
# 11    6
# 12    9
# 13    4
# 14    2
# 15    8
# 16    9
# 17    8
# 18    8
# 19    3
# 20    6
# 21    6
# 22    4
# 23    7
# 24    2
# 25    8
# 26    3
# 27    7
# 28    4
# 29    5
# Name: pa1, dtype: int64

# %%
d4["Total"] = d4["pa1"]+ d4["Hulk"]+ d4["ram"]
d4
# Out:
#     ram  pa1  Hulk  Total
# 0     2    4     7     13
# 1     4    8     3     15
# 2     8    9     9     26
# 3     7    8     4     19
# 4     1    5     5     11
# 5     9    9     3     21
# 6     4    9     7     20
# 7     3    2     5     10
# 8     1    6     6     13
# 9     6    2     3     11
# 10    5    5     7     17
# 11    8    6     5     19
# 12    5    9     4     18
# 13    8    4     3     15
# 14    4    2     6     12
# 15    4    8     7     19
# 16    4    9     4     17
# 17    5    8     3     16
# 18    6    8     6     20
# 19    2    3     7     12
# 20    5    6     6     17
# 21    7    6     5     18
# 22    9    4     6     19
# 23    6    7     5     18
# 24    4    2     9     15
# 25    8    8     5     21
# 26    4    3     5     12
# 27    8    7     3     18
# 28    3    4     5     12
# 29    9    5     5     19

# %%
employees = [
    ['rk', 100, 19000],
    ['js', 101, 22000],
    ['am', 102, 18500],
    ['pt', 103, 25000],
    ['ks', 104, 21000],
    ['rv', 105, 20000],
    ['sl', 106, 23000],
    ['mj', 107, 19500],
    ['dp', 108, 24000],
     ['cl', 109, 20500]
  ]
employees
# Out:
# [['rk', 100, 19000],
#  ['js', 101, 22000],
#  ['am', 102, 18500],
#  ['pt', 103, 25000],
#  ['ks', 104, 21000],
#  ['rv', 105, 20000],
#  ['sl', 106, 23000],
#  ['mj', 107, 19500],
#  ['dp', 108, 24000],
#  ['cl', 109, 20500]]

# %%
p1 = pd.DataFrame(employees,columns =["name","idno","salary"])
p1
# Out:
#   name  idno  salary
# 0   rk   100   19000
# 1   js   101   22000
# 2   am   102   18500
# 3   pt   103   25000
# 4   ks   104   21000
# 5   rv   105   20000
# 6   sl   106   23000
# 7   mj   107   19500
# 8   dp   108   24000
# 9   cl   109   20500

# %%
p1[p1.salary>=25000]
# Out:
#   name  idno  salary
# 3   pt   103   25000

# %%
p1[p1.salary<=20000]
# Out:
#   name  idno  salary
# 0   rk   100   19000
# 2   am   102   18500
# 5   rv   105   20000
# 7   mj   107   19500

# %%
new_row = pd.DataFrame([{"name":"pavan", "idno":np.nan,"salary":56500}])
p1 = pd.concat([p1, new_row], ignore_index=True)
p1
# Out:
#      name   idno  salary
# 0      rk  100.0   19000
# 1      js  101.0   22000
# 2      am  102.0   18500
# 3      pt  103.0   25000
# 4      ks  104.0   21000
# 5      rv  105.0   20000
# 6      sl  106.0   23000
# 7      mj  107.0   19500
# 8      dp  108.0   24000
# 9      cl  109.0   20500
# 10  pavan  100.0   35000
# 11  pavan    NaN   35000
# 12  pavan    NaN   56500

# %%
p1.isnull()
# Out:
#      name   idno  salary
# 0   False  False   False
# 1   False  False   False
# 2   False  False   False
# 3   False  False   False
# 4   False  False   False
# 5   False  False   False
# 6   False  False   False
# 7   False  False   False
# 8   False  False   False
# 9   False  False   False
# 10  False  False   False
# 11  False   True   False
# 12  False   True   False

# %%
p1.isnull().sum()
# Out:
# name      0
# idno      2
# salary    0
# dtype: int64

# %%
samba = p1.dropna()

# %%
samba
# Out:
#      name   idno  salary
# 0      rk  100.0   19000
# 1      js  101.0   22000
# 2      am  102.0   18500
# 3      pt  103.0   25000
# 4      ks  104.0   21000
# 5      rv  105.0   20000
# 6      sl  106.0   23000
# 7      mj  107.0   19500
# 8      dp  108.0   24000
# 9      cl  109.0   20500
# 10  pavan  100.0   35000

# %% [markdown]
# ** groupby**

# %%
df = pd.DataFrame({'Animal':['falcon','falcon','parrot','parrot'],'max_speed':[600,500,900,400]})
df
# Out:
#    Animal  max_speed
# 0  falcon        600
# 1  falcon        500
# 2  parrot        900
# 3  parrot        400

# %%
df.groupby(['Animal']).mean()
# Out:
#         max_speed
# Animal
# falcon      550.0
# parrot      650.0

# %%
df.groupby(["Animal"]).sum()
# Out:
#         max_speed
# Animal
# falcon       1100
# parrot       1300

# %%
df_csv = pd.read_csv("/student-data.csv")
df_csv.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences passed
# 0       no       no       4         3      4    1    1      3        6     no
# 1      yes       no       5         3      3    1    1      3        4     no
# 2      yes       no       4         3      2    2    3      3       10    yes
# 3      yes      yes       3         2      2    1    1      5        2    yes
# 4       no       no       4         3      2    1    2      5        4    yes
#
# [5 rows x 31 columns]

# %%
df_csv.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 390  ...       no       no       5         5      4    4    5      4       11
# 391  ...      yes       no       2         4      5    3    4      2        3
# 392  ...       no       no       5         5      3    3    3      3        3
# 393  ...      yes       no       4         4      1    3    4      5        0
# 394  ...      yes       no       3         2      3    3    3      5        5
#
#     passed
# 390     no
# 391    yes
# ...

# %%
df_csv.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 390   False  False  False    False    False    False  False  False  False
# 391   False  False  False    False    False    False  False  False  False
# 392   False  False  False    False    False    False  False  False  False
# 393   False  False  False    False    False    False  False  False  False
# 394   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  internet  romantic  famrel  freetime  goout   Dalc   Walc  \
# ...

# %%
df_csv.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# passed        0
# dtype: int64

# %%
df_csv.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df_csv.sort_values(by = "age").head(18)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 21      GP   M   15       U     GT3       T     4     4    health    health
# 20      GP   M   15       U     GT3       T     4     3   teacher     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 36      GP   M   15       U     LE3       T     4     3   teacher  services
# 38      GP   F   15       R     GT3       T     3     4  services    health
# 39      GP   F   15       R     GT3       T     2     2   at_home     other
# 41      GP   M   15       U     LE3       T     4     4   teacher     other
# 42      GP   M   15       U     GT3       T     4     4  services   teacher
# 43      GP   M   15       U     GT3       T     2     2  services  services
# 45      GP   F   15       U     LE3       A     4     3     other     other
# ...

# %%
df_csv.sort_values(by = "age",ascending=False).head(20)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 247     GP   M   22       U     GT3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 376     MS   F   20       U     GT3       T     4     2    health     other
# 306     GP   M   20       U     GT3       A     3     2  services     other
# 314     GP   F   19       U     GT3       T     1     1   at_home    health
# 308     GP   M   19       R     GT3       T     3     3     other  services
# 370     MS   F   19       U     LE3       T     3     2  services  services
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
# 336     GP   F   19       R     GT3       A     3     1  services   at_home
# 313     GP   F   19       U     LE3       T     3     2  services     other
# ...

# %%
df_csv.shape[0]
# Out:
# 395

# %%
df_csv.shape[1]
# Out:
# 31

# %%
df_csv.loc[14,['sex']]
# Out:
# sex    M
# Name: 14, dtype: object

# %%
df_csv
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...
